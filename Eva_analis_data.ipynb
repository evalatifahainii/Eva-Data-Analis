# %%
# !pip install streamlit
# !pip install pyngrok
# !pip install pandas seaborn matplotlib
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.39.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.8.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<6,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_list = os.listdir('/content/data') # daftarkan isi direktori 'data'
dataframes = []

for i in range(len(dataset_list)):
    dataframes.append(pd.read_csv(os.path.join('/content/data', dataset_list[i])))

# %%
dataset_list
# Out:
# ['PRSA_Data_Nongzhanguan_20130301-20170228.csv',
#  'PRSA_Data_Wanshouxigong_20130301-20170228.csv',
#  'PRSA_Data_Guanyuan_20130301-20170228.csv',
#  'PRSA_Data_Changping_20130301-20170228.csv',
#  'PRSA_Data_Tiantan_20130301-20170228.csv',
#  'PRSA_Data_Gucheng_20130301-20170228.csv',
#  'PRSA_Data_Dingling_20130301-20170228.csv',
#  'PRSA_Data_Aotizhongxin_20130301-20170228.csv',
#  'PRSA_Data_Shunyi_20130301-20170228.csv',
#  'PRSA_Data_Huairou_20130301-20170228.csv',
#  'PRSA_Data_Wanliu_20130301-20170228.csv',
#  'PRSA_Data_Dongsi_20130301-20170228.csv']

# %%
aotizhongxin_df, changping_df, dingling_df, dongsi_df, guanyuan_df, gucheng_df, huairou_df, nongzhanguan_df, shunyi_df, tiantan_df, wanliu_df, wanshouxigong_df = dataframes

# %%
aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
aotizhongxin_df.duplicated().sum()
# Out:
# 0

# %%
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
changping_df.duplicated().sum()
# Out:
# 0

# %%
dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
dingling_df.duplicated().sum()
# Out:
# 0

# %%
dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
dongsi_df.duplicated().sum()
# Out:
# 0

# %%
guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
guanyuan_df.duplicated().sum()
# Out:
# 0

# %%
gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
gucheng_df.duplicated().sum()
# Out:
# 0

# %%
huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
huairou_df.duplicated().sum()
# Out:
# 0

# %%
nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
nongzhanguan_df.duplicated().sum()
# Out:
# 0

# %%
shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
shunyi_df.duplicated().sum()
# Out:
# 0

# %%
tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
tiantan_df.duplicated().sum()
# Out:
# 0

# %%
wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
wanliu_df.duplicated().sum()
# Out:
# 0

# %%
wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
wanshouxigong_df.duplicated().sum()
# Out:
# 0

# %%
aotizhongxin_df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0   4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0   6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0   5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0   5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0   6.0  21.0  200.0  77.0  -1.9
# 5   6  2013      3    1     5    3.0   3.0  13.0  21.0  300.0  77.0  -2.4
# 6   7  2013      3    1     6    4.0   4.0  15.0  32.0  300.0  62.0  -2.5
# 7   8  2013      3    1     7    3.0   7.0  14.0  45.0  400.0  48.0  -1.4
# 8   9  2013      3    1     8    3.0   6.0  13.0  49.0  400.0  46.0  -0.3
# 9  10  2013      3    1     9   11.0  14.0   9.0  28.0  400.0  68.0   0.4
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan
# 5  1027.5 -21.3   0.0   NW   2.4  Nongzhanguan
# 6  1028.2 -20.4   0.0   NW   2.2  Nongzhanguan
# 7  1029.5 -20.4   0.0  NNW   3.0  Nongzhanguan
# 8  1030.4 -21.2   0.0   NW   4.6  Nongzhanguan
# 9  1030.5 -23.3   0.0    N   5.5  Nongzhanguan

# %%
aotizhongxin_df = aotizhongxin_df.interpolate(method='linear')
changping_df = changping_df.interpolate(method='linear')
dingling_df = dingling_df.interpolate(method='linear')
dongsi_df = dongsi_df.interpolate(method='linear')
guanyuan_df = guanyuan_df.interpolate(method='linear')
gucheng_df = gucheng_df.interpolate(method='linear')
huairou_df = huairou_df.interpolate(method='linear')
nongzhanguan_df = nongzhanguan_df.interpolate(method='linear')
shunyi_df = shunyi_df.interpolate(method='linear')
tiantan_df = tiantan_df.interpolate(method='linear')
wanliu_df = wanliu_df.interpolate(method='linear')
wanshouxigong_df = wanshouxigong_df.interpolate(method='linear')
# Out:
# <ipython-input-54-30ffd8952b6d>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   aotizhongxin_df = aotizhongxin_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   changping_df = changping_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dingling_df = dingling_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dongsi_df = dongsi_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:5: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   guanyuan_df = guanyuan_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:6: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   gucheng_df = gucheng_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:7: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   huairou_df = huairou_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:8: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   nongzhanguan_df = nongzhanguan_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   shunyi_df = shunyi_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:10: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   tiantan_df = tiantan_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:11: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   wanliu_df = wanliu_df.interpolate(method='linear')
# <ipython-input-54-30ffd8952b6d>:12: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   wanshouxigong_df = wanshouxigong_df.interpolate(method='linear')

# %%
aotizhongxin_df['wd'].value_counts()
# Out:
# wd
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: count, dtype: int64

# %%
aotizhongxin_df['wd'].fillna(value='NA', inplace=True)
# Out:
# <ipython-input-55-80fa3f65983c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df['wd'].fillna(value='NA', inplace=True)

# %%
aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
changping_df['wd'].value_counts()
# Out:
# wd
# NE     3568
# SW     3428
# ENE    3080
# E      2807
# WNW    2565
# NW     2552
# WSW    2546
# W      2464
# SSW    2457
# ESE    1772
# NNE    1564
# S      1506
# SE     1279
# NNW    1187
# N      1176
# SSE    1034
# Name: count, dtype: int64

# %%
changping_df['wd'].fillna(value='NNW', inplace=True)
# Out:
# <ipython-input-58-dc43f9b3c568>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_df['wd'].fillna(value='NNW', inplace=True)

# %%
changping_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
dingling_df['wd'].value_counts()
# Out:
# wd
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64

# %%
dingling_df['wd'].fillna(value='NNW', inplace=True)
# Out:
# <ipython-input-61-d7b8049737c9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_df['wd'].fillna(value='NNW', inplace=True)

# %%
dingling_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
dongsi_df['wd'].value_counts()
# Out:
# wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
dongsi_df['wd'].fillna(value='ENE', inplace=True)
# Out:
# <ipython-input-65-476f42990174>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_df['wd'].fillna(value='ENE', inplace=True)

# %%
dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
guanyuan_df['wd'].value_counts()
# Out:
# wd
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: count, dtype: int64

# %%
guanyuan_df['wd'].fillna(value='NE', inplace=True)
# Out:
# <ipython-input-68-d78c6567b98c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_df['wd'].fillna(value='NE', inplace=True)

# %%
guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
gucheng_df['wd'].value_counts()
# Out:
# wd
# N      3949
# NE     3119
# SSW    2762
# NW     2758
# NNE    2602
# S      2343
# W      2331
# WNW    2073
# SW     1993
# ENE    1885
# WSW    1621
# NNW    1614
# E      1607
# SSE    1553
# ESE    1353
# SE     1342
# Name: count, dtype: int64

# %%
gucheng_df['wd'].fillna(value='N', inplace=True)
# Out:
# <ipython-input-71-4d420a31a0fa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_df['wd'].fillna(value='N', inplace=True)

# %%
gucheng_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2        20
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# station     0
# dtype: int64

# %%
huairou_df['wd'].value_counts()
# Out:
# wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
huairou_df['wd'].fillna(value='Nw', inplace=True)
# Out:
# <ipython-input-74-aa870a72b1c8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_df['wd'].fillna(value='Nw', inplace=True)

# %%
huairou_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        2
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
nongzhanguan_df['wd'].value_counts()
# Out:
# wd
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64

# %%
nongzhanguan_df['wd'].fillna(value='ENE', inplace=True)
# Out:
# <ipython-input-77-1883964975c3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_df['wd'].fillna(value='ENE', inplace=True)

# %%
nongzhanguan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
shunyi_df['wd'].value_counts()
# Out:
# wd
# NNE    4540
# N      3877
# NE     3351
# SSE    2963
# SE     2665
# S      2613
# NW     2446
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      973
# WSW     737
# Name: count, dtype: int64

# %%
shunyi_df['wd'].fillna(value='NNE', inplace=True)
# Out:
# <ipython-input-80-c89434e13b44>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_df['wd'].fillna(value='NNE', inplace=True)

# %%
shunyi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
tiantan_df['wd'].value_counts()
# Out:
# wd
# NW     4943
# WNW    4876
# NE     2252
# E      2159
# W      2138
# SE     2113
# ENE    2026
# ESE    2022
# SW     1797
# NNE    1687
# NNW    1663
# SSE    1573
# WSW    1468
# N      1367
# SSW    1350
# S      1328
# Name: count, dtype: int64

# %%
tiantan_df['wd'].fillna(value='ENE', inplace=True)
# Out:
# <ipython-input-83-4a78d68d1896>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_df['wd'].fillna(value='ENE', inplace=True)

# %%
tiantan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
wanliu_df['wd'].value_counts()
# Out:
# wd
# NE     6703
# SW     4644
# ENE    3642
# NNE    3327
# N      3219
# WSW    2529
# SSW    2101
# NNW    1397
# W      1335
# E      1264
# NW     1107
# S       966
# WNW     813
# SE      707
# SSE     615
# ESE     572
# Name: count, dtype: int64

# %%
wanliu_df['wd'].fillna(value='NE', inplace=True)
# Out:
# <ipython-input-87-7f6ec737e63e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_df['wd'].fillna(value='NE', inplace=True)

# %%
wanliu_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
wanshouxigong_df['wd'].value_counts()
# Out:
# wd
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: count, dtype: int64

# %%
wanshouxigong_df['wd'].fillna(value='NE', inplace=True)
# Out:
# <ipython-input-90-0cf27c7d72ce>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_df['wd'].fillna(value='NE', inplace=True)

# %%
wanshouxigong_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
all_df = pd.concat([aotizhongxin_df, changping_df, dingling_df, dongsi_df, guanyuan_df, gucheng_df, huairou_df, nongzhanguan_df, shunyi_df, tiantan_df, wanliu_df, wanshouxigong_df], ignore_index=True)

# %%
all_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       11.500000      79.839718     104.910268      15.913090
# std         6.922195      80.950217      92.431422      21.896609
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  420746.000000  420768.000000  420768.000000  420768.000000
# mean       50.601416    1235.682649      57.237872      13.531692
# std        35.171276    1161.790893      57.135195      11.437867
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      10.000000       3.100000
# 50%        43.000000     900.000000      44.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean     1010.753337       2.482421       0.064428       1.730034
# std        10.474302      13.797675       0.820638       1.246674
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.000000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %%
all_df.groupby(by='station').agg({
    "PM2.5":['max', 'mean'],
    "PM10":['max', 'mean'],
    "NO2":['max', 'mean'],
    "SO2":['max', 'mean'],
    "CO":['max', 'mean'],
    "O3":['max', 'mean']
})
# Out:
#                PM2.5              PM10                NO2               SO2  \
#                  max       mean    max        mean    max       mean    max
# station
# Aotizhongxin   898.0  82.540623  984.0  110.210033  290.0  59.074106  341.0
# Changping      882.0  70.986438  999.0   94.788575  226.0  44.206153  310.0
# Dingling       881.0  66.845557  905.0   84.113713  205.0  27.305033  156.0
# Dongsi         737.0  86.144243  955.0  110.347617  258.0  53.953078  300.0
# Guanyuan       680.0  82.897522  999.0  109.372349  270.0  58.139298  293.0
# Gucheng        770.0  84.074802  994.0  119.261567  276.0  55.851320  500.0
# Huairou        762.0  69.501747  993.0   92.422670  231.0  32.077275  315.0
# Nongzhanguan   844.0  85.079472  995.0  109.384022  273.0  58.095053  257.0
# Shunyi         941.0  79.437962  999.0   99.271936  258.0  44.094695  239.0
# Tiantan        821.0  82.033097  988.0  106.537076  241.0  53.258828  273.0
# Wanliu         957.0  83.467612  951.0  110.707858  264.0  65.668418  282.0
# Wanshouxigong  999.0  85.067548  961.0  112.505795  251.0  55.495402  411.0
#
#                                CO                      O3
#                     mean      max         mean        max       mean
# station
# Aotizhongxin   17.459251  10000.0  1264.692405   423.0000  55.328626
# Changping      14.943066  10000.0  1156.990246   429.0000  57.976253
# Dingling       11.797849  10000.0   925.111838   500.0000  70.530792
# Dongsi         18.506142  10000.0  1331.913045  1071.0000  57.700357
# Guanyuan       17.609312  10000.0  1258.327045   415.0000  54.817142
# Gucheng        15.705821  10000.0  1338.100060   450.0000  58.000001
# Huairou        12.446681  10000.0  1019.671871   444.0000  60.872173
# Nongzhanguan   18.760102  10000.0  1327.767611   390.0000  58.432876
# Shunyi         13.445971  10000.0  1197.904660   351.7164  54.218810
# Tiantan        14.510018  10000.0  1305.333262   674.0000  56.148077
# Wanliu         18.409514  10000.0  1328.761180   364.0000  46.909375
# Wanshouxigong  17.363354   9800.0  1373.618569   358.0000  55.919979

# %%
pollutant_all_df = all_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']]

# %%
pollutant_all_df.corr()
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3
# PM2.5  1.000000  0.878874  0.478223  0.664300  0.780165 -0.149508
# PM10   0.878874  1.000000  0.460572  0.645576  0.691887 -0.110443
# SO2    0.478223  0.460572  1.000000  0.495821  0.522678 -0.165311
# NO2    0.664300  0.645576  0.495821  1.000000  0.694035 -0.465907
# CO     0.780165  0.691887  0.522678  0.694035  1.000000 -0.306979
# O3    -0.149508 -0.110443 -0.165311 -0.465907 -0.306979  1.000000

# %%
pollutant_hour_df = all_df.groupby(by='hour').agg({
    "PM2.5":'mean',
    "PM10":'mean',
    "NO2":'mean',
    "SO2":'mean',
    "CO":'mean',
    "O3":'mean'
}).reset_index()
pollutant_hour_df
# Out:
#     hour      PM2.5        PM10        NO2        SO2           CO          O3
# 0      0  87.696481  115.206576  57.862759  15.138782  1376.587941   42.057909
# 1      1  86.848406  112.031010  55.692319  15.159580  1377.964402   38.381854
# 2      2  84.803844  107.648670  53.314599  14.916881  1327.441592   34.542478
# 3      3  82.212727  102.659579  52.250600  13.741630  1275.936632   32.323738
# 4      4  79.465989   97.945965  51.607569  13.250695  1246.701409   30.723837
# 5      5  76.538028   94.000502  50.626877  12.827728  1255.430381   28.839288
# 6      6  74.289174   92.371314  50.807232  12.795053  1272.049460   27.689135
# 7      7  73.424078   94.006330  52.634535  13.275031  1298.724184   25.884621
# 8      8  74.403840   98.552736  54.288793  14.853987  1342.035501   27.530761
# 9      9  76.061597  100.988080  52.717756  17.375883  1333.891685   35.112930
# 10    10  77.126229  101.016970  49.881712  19.156080  1287.420375   46.483027
# 11    11  77.142663   99.661052  46.774393  19.657236  1221.378880   59.558560
# 12    12  76.548181   97.494451  43.684220  19.423906  1156.889714   73.274273
# 13    13  76.048575   95.664931  40.643737  18.884909  1091.503199   86.215308
# 14    14  75.462557   95.557480  38.817409  18.128276  1044.870319   95.854960
# 15    15  74.560780   96.817121  38.535077  17.501247  1026.458111  100.875321
# 16    16  74.399300   99.389631  39.575373  16.949019  1011.614961  101.960980
# 17    17  75.524938  103.695197  42.842239  16.251484  1042.222452   98.325161
# 18    18  78.014513  110.334883  48.507594  15.498482  1112.455931   89.750067
# 19    19  82.503641  117.270537  54.592679  15.348508  1205.663720   78.230416
# 20    20  86.636117  122.314940  58.413971  15.428480  1279.465915   67.148320
# 21    21  88.813470  123.381469  60.247911  15.444936  1334.038841   57.315620
# 22    22  89.032249  121.175438  60.570259  15.480776  1360.973037   50.109014
# 23    23  88.595867  118.661565  59.543006  15.425571  1374.664941   45.521345

# %%
pollutant_pm25 = all_df.groupby(by='station').agg({"PM2.5":'mean'}).sort_values(by='PM2.5', ascending=False).reset_index()
pollutant_pm25.rename(columns={
    'station':'Distrik',
    'PM2.5':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
pollutant_pm10 = all_df.groupby(by='station').agg({"PM10":'mean'}).sort_values(by='PM10', ascending=False).reset_index()
pollutant_pm10.rename(columns={
    'station':'Distrik',
    'PM10':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
pollutant_so2 = all_df.groupby(by='station').agg({"SO2":'mean'}).sort_values(by='SO2', ascending=False).reset_index()
pollutant_so2.rename(columns={
    'station':'Distrik',
    'SO2':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
pollutant_no2 = all_df.groupby(by='station').agg({"NO2":'mean'}).sort_values(by='NO2', ascending=False).reset_index()
pollutant_no2.rename(columns={
    'station':'Distrik',
    'NO2':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
pollutant_co = all_df.groupby(by='station').agg({"CO":'mean'}).sort_values(by='CO', ascending=False).reset_index()
pollutant_co.rename(columns={
    'station':'Distrik',
    'CO':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
pollutant_o3 = all_df.groupby(by='station').agg({"O3":'mean'}).sort_values(by='O3', ascending=False).reset_index()
pollutant_o3.rename(columns={
    'station':'Distrik',
    'O3':'Rata-Rata Konsentrasi'
}, inplace=True)

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(24,18))
colors = ["#408ABF", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_pm25.head(5), palette=colors, ax=ax[0][0])
ax[0][0].set_ylabel(None)
ax[0][0].set_title("Polutan PM2.5", loc="center", fontsize=15)
ax[0][0].tick_params(axis ='y', labelsize=12)

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_pm10.head(5), palette=colors, ax=ax[0][1])
ax[0][1].set_ylabel(None)
ax[0][1].set_title("Polutan PM10", loc="center", fontsize=15)
ax[0][1].tick_params(axis ='y', labelsize=12)

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_so2.head(5), palette=colors, ax=ax[1][0])
ax[1][0].set_ylabel(None)
ax[1][0].set_title("Polutan SO2", loc="center", fontsize=15)
ax[1][0].tick_params(axis ='y', labelsize=12)

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_no2.head(5), palette=colors, ax=ax[1][1])
ax[1][1].set_ylabel(None)
ax[1][1].set_title("Polutan NO2", loc="center", fontsize=15)
ax[1][1].tick_params(axis ='y', labelsize=12)

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_co.head(5), palette=colors, ax=ax[2][0])
ax[2][0].set_ylabel(None)
ax[2][0].set_title("Polutan CO", loc="center", fontsize=15)
ax[2][0].tick_params(axis ='y', labelsize=12)

sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_o3.head(5), palette=colors, ax=ax[2][1])
ax[2][1].set_ylabel(None)
ax[2][1].set_title("Polutan O3", loc="center", fontsize=15)
ax[2][1].tick_params(axis ='y', labelsize=12)

plt.suptitle("Konsentrasi Polutan Paling Tinggi", fontsize=30)
# Out:
# <ipython-input-104-03dc601d90e4>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_pm25.head(5), palette=colors, ax=ax[0][0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <ipython-input-104-03dc601d90e4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_pm10.head(5), palette=colors, ax=ax[0][1])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <ipython-input-104-03dc601d90e4>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_so2.head(5), palette=colors, ax=ax[1][0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <ipython-input-104-03dc601d90e4>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_no2.head(5), palette=colors, ax=ax[1][1])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <ipython-input-104-03dc601d90e4>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_co.head(5), palette=colors, ax=ax[2][0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <ipython-input-104-03dc601d90e4>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rata-Rata Konsentrasi', y='Distrik', data=pollutant_o3.head(5), palette=colors, ax=ax[2][1])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0.5, 0.98, 'Konsentrasi Polutan Paling Tinggi')

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(24,12))

sns.scatterplot(x='PM2.5', y='PM2.5', data=pollutant_all_df, palette=colors, ax=ax[0][0], s=10)
ax[0][0].set_title("Polutan PM2.5", loc="center", fontsize=15)

sns.scatterplot(x='PM2.5', y='PM10', data=pollutant_all_df, palette=colors, ax=ax[0][1], s=10)
ax[0][1].set_title("Polutan PM10", loc="center", fontsize=15)

sns.scatterplot(x='PM2.5', y='SO2', data=pollutant_all_df, palette=colors, ax=ax[0][2], s=10)
ax[0][2].set_title("Polutan SO2", loc="center", fontsize=15)

sns.scatterplot(x='PM2.5', y='NO2', data=pollutant_all_df, palette=colors, ax=ax[1][0], s=10)
ax[1][0].set_title("Polutan NO2", loc="center", fontsize=15)

sns.scatterplot(x='PM2.5', y='CO', data=pollutant_all_df, palette=colors, ax=ax[1][1], s=10)
ax[1][1].set_title("Polutan CO", loc="center", fontsize=15)

sns.scatterplot(x='PM2.5', y='O3', data=pollutant_all_df, palette=colors, ax=ax[1][2], s=10)
ax[1][2].set_title("Polutan O3", loc="center", fontsize=15)

plt.suptitle("Korelasi Polutan PM2.5 Dengan Polutan Lain", fontsize=30)
# Out:
# <ipython-input-106-5e2050f6b6fe>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='PM2.5', data=pollutant_all_df, palette=colors, ax=ax[0][0], s=10)
# <ipython-input-106-5e2050f6b6fe>:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='PM10', data=pollutant_all_df, palette=colors, ax=ax[0][1], s=10)
# <ipython-input-106-5e2050f6b6fe>:9: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='SO2', data=pollutant_all_df, palette=colors, ax=ax[0][2], s=10)
# <ipython-input-106-5e2050f6b6fe>:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='NO2', data=pollutant_all_df, palette=colors, ax=ax[1][0], s=10)
# <ipython-input-106-5e2050f6b6fe>:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='CO', data=pollutant_all_df, palette=colors, ax=ax[1][1], s=10)
# <ipython-input-106-5e2050f6b6fe>:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='PM2.5', y='O3', data=pollutant_all_df, palette=colors, ax=ax[1][2], s=10)
# Text(0.5, 0.98, 'Korelasi Polutan PM2.5 Dengan Polutan Lain')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['PM2.5'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan PM2.5 (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan PM2.5 (per Jam)')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['PM10'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan PM10 (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan PM10 (per Jam)')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['SO2'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan SO2 (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan SO2 (per Jam)')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['NO2'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan NO2 (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan NO2 (per Jam)')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['CO'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan CO (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan CO (per Jam)')

# %%
plt.figure(figsize=(12,4))
plt.plot(pollutant_hour_df['hour'],
         pollutant_hour_df['O3'],
         marker='o')
plt.xticks(pollutant_hour_df['hour'])

plt.suptitle("Rata-Rata Konsentrasi Polutan O3 (per Jam)", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Rata-Rata Konsentrasi Polutan O3 (per Jam)')

# %%
# Menyimpan dataset dalam bentuk CSV untuk membuat dashboard dengan library streamlit

all_df = all_df.drop(['No'], axis=1)
all_df.to_csv('dataset.csv', index=False)

# %% [markdown]
# Nama: Eva Latifah`Ainii ML-72
